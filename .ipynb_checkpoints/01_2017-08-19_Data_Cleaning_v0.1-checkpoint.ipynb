# %%
# GLANSOWANIE_SOCJOLEKTU(filepath) processes the raw text file (filepath) and saves it as "Dobre Slowa.txt" 
# warning: The output may contain słowa that are not actually dobre. 

# todo:
#    1. Delete words like "HAHAHAHAHAHA", "BYŁO", "GIPHY", "KAAPOK",  etc

def GLANSOWANIE_SOCJOLEKTU(filename = "Surowe Slowa.txt"):


# 1. Opening the text file 
    with open("Surowe Slowa.txt", 'r', encoding='utf-8') as f:
        text = f.read()

        caps_words = str()   # processed words will be added to this string 
        for word in words:
            if word.isupper() == True:
                if word not in ["JANUARY","FEBRUARY","MARCH","APRIL","MAY","JUNE",
                                "JULY","AUGUST,""SEPTEMBER","OCTOBER","NOVEMBER","DECEMBER"]:
                    if not word.startswith(("!","?","(",")","*",":","!","?","(",")","*",":",".")):
                        if not word.endswith(("!","?","(",")","*",":","!","?","(",")","*",":",".")):
                            if len(word)>1:
                                if word not in caps_split:
                                    caps_words = caps_words + str(" ") + str(word)

        text_file = open("Dobre Slowa.txt", "w")
        text_file.write(caps_words.split())
        text_file.close()

    return caps_words

# %%
GLANSOWANIE_SOCJOLEKTU(filename = "Surowe Slowa.txt")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-80f4016b40ab> in <module>()
# ----> 1 GLANSOWANIE_SOCJOLEKTU(filename = "Surowe Slowa.txt")
#
# <ipython-input-131-efea1d199a18> in GLANSOWANIE_SOCJOLEKTU(filename)
#      24
#      25         text_file = open("Dobre Slowa.txt", "w")
# ---> 26         text_file.write(caps_words.split())
#      27         text_file.close()
#      28
#
# TypeError: write() argument must be str, not list

# %%
GLANSOWANIE_SOCJOLEKTU(filename = "Surowe Slowa.txt").split()
# Out:
# ['SKAFANDER',
#  'BRYLOK',
#  'SEMAFOR',
#  'WIERZBNO',
#  'SYFON',
#  'PLANDEKA',
#  'WYWAR',
#  'BRZESZCZOT',
#  'KATAPULTA',
#  'TRAPER',
#  'PETARDA',
#  'OBWARZANKI',
#  'BAJZEL',
#  'BARYKADA',
#  'BARACHŁO',
#  'BUKŁAKI',
#  'BŁACHOSTKA',
#  'PRYNCYPAŁ',
#  'DOBRE',
#  'DYLIŻANS',
#  'OBWIEDNIA',
#  'JESIOTR',
#  'KLEKS',
#  'KLOPS',
#  'KŁYKIEĆ',
#  'WERSALKA',
#  'PASODOBLE',
#  'BRYSTOL',
#  'OBERŻYNA',
#  'OBŻARTUCH',
#  'BOCZNIAKI',
#  'FARFOCLE',
#  'KALAREPA',
#  'FLANELOWY',
#  'CHERLAK',
#  'RETRO',
#  'TAMBURYN',
#  'TABORET',
#  'FLEJTUCH',
#  'FAJTŁAPA',
#  'DUREŃ',
#  'OBELŻYWE',
#  'FELGA',
#  'KOŁPAK',
#  'KOŁPAK',
#  'BŁOTNIAKI',
#  'PANDEMONIUM',
#  'PURCHAWKA',
#  'PROTEZA',
#  'SZYMEK',
#  'SZKATUŁKA',
#  'SZMELC',
#  'HAHAHAHAHA',
#  'SŁODZIAK',
#  'LAMINACJA',
#  'GABLOTA',
#  'WITRYNA',
#  'LAMINACJA',
#  'GABLOTA',
#  'WITRYNA',
#  'PRAWAŻKA',
#  'BURSA',
#  'WYKIDAJŁO',
#  'AKRON',
#  'BRYKIET',
#  'DYLEMAT',
#  'MAJTOCHY',
#  'RAJTUZY',
#  'KALESONY',
#  'SMACZEK',
#  'BROWAR',
#  'KOSODRZEWINA',
#  'PLANKTON',
#  'KRA',
#  'PIŻMO',
#  'BYLICA',
#  'PRZEPUKLINA',
#  'WENFLON',
#  'NAROŚL',
#  'BULWA',
#  'PULCHNIAK',
#  'KONTRABANDA',
#  'HULANKI',
#  'SWAWOLE',
#  'DRYBLAS',
#  'GUMOLEUM',
#  'GLEDICZJA',
#  'PLEJSTOCEN',
#  'OROGENEZA',
#  'MORENA',
#  'GEOLOGIA',
#  'SKRZEP',
#  'SKAFANDER',
#  'SZYMEK',
#  'SZYMEK',
#  'BUTONIERKA',
#  'BAMBOSZE',
#  'BĄBEL',
#  'PAMPUCHY',
#  'PROBOSZCZ',
#  'KAPODASTER',
#  'KATARAKTA',
#  'MENZURA',
#  'MIERZWIĆ',
#  'BERBEĆ',
#  'WIGWAM',
#  'DRYBLAS',
#  'BYŁO',
#  'GIPHY',
#  'SZMUL',
#  'KREPINA',
#  'BIBUŁA',
#  'HALIBUT',
#  'KLEMENTYNKI',
#  'CZEMPION',
#  'KLAKIERKI',
#  'DUSZPASTERSTWO',
#  'KAPŁAN',
#  'MOLEKUŁY',
#  'SZASZŁYKI',
#  'MODYSTKI',
#  'MOTYKA',
#  'KAPUŚNIAK',
#  'TURBINA',
#  'SZTACHETA',
#  'WARZĄCHEW',
#  'CHOCHLA',
#  'PIELĘGNACJA',
#  'POWŁOKA',
#  'APARATURA',
#  'PĄK',
#  'PULPA',
#  'GANGRENA',
#  'DEGRENGOLADA',
#  'SERPENTYNA',
#  'BUFET',
#  'KANTYNA',
#  'BUDRYS',
#  'BURSA',
#  'GWINT',
#  'RORATY',
#  'RABUNEK',
#  'PARAFINA',
#  'PANTOFEL',
#  'PLAKIETKA',
#  'BROSZURA',
#  'SKOROSZYT',
#  'KLASER',
#  'WĘGŁO',
#  'WĘGIEL',
#  'WĘGIEŁ',
#  'PELARGONIA',
#  'PERLIKI',
#  'TELEFONOWAĆ',
#  'IMPULSY',
#  'BIUSTONOSZ',
#  'BIUSTONOSZ',
#  'UTC',
#  'DUPSKO',
#  'TERAKOTA',
#  'GOŁOLEDŹ',
#  'SCHOLASTYKA',
#  'ZAKRYSTIA',
#  'NOKTOWIZOR',
#  'WIGWAM',
#  'HIPERBOLA',
#  'MENZURA',
#  'ABDYKACJA',
#  'AKOLITA',
#  'BRECHA',
#  'SJP',
#  'ŚRODOWISKOWO',
#  'ŁOMIE',
#  'LANDRYNKA',
#  'SZKLIWO',
#  'SZAMBELAN',
#  'KAPOK',
#  'ANTYKWARIAT',
#  'KAPOK',
#  'KAAAPOK',
#  'BLUZGAĆ',
#  'KREDENS',
#  'REBUS',
#  'ELIMINACJA',
#  'KLEJNOTY',
#  'UBIKACJA',
#  'PALICZEK',
#  'KLUSECZKA',
#  'KIBEL',
#  'KAPLICA',
#  'KĘDZIOR',
#  'KRUSZGANEK',
#  'MARMOLADA',
#  'SERDEL',
#  'SMALIĆ',
#  'CHOLEWKI',
#  'ŹDŹBŁO',
#  'ROLMOPS',
#  'KLOCUSZEK',
#  'ŁAKOCIE',
#  'ŁAKOMCZUCH',
#  'ARRAS',
#  'ŻORŻETA',
#  'LUBRYKANT',
#  'KARBURATOR',
#  'MAŁŻONKA',
#  'INKUBATOR',
#  'GARSONKA',
#  'KRZTA',
#  'BLEFOWAĆ',
#  'BULDOŻER',
#  'TUPET',
#  'SZCZEPKI',
#  'POTASZNIA',
#  'BAKAŁAŻEWO',
#  'MOTULE',
#  'BECEJŁY',
#  'PRUDZISZKI',
#  'CHĘDOŻENIE',
#  'DROPS',
#  'KĘS',
#  'DYRDYMAŁY',
#  'PUZDERKO',
#  'GROBLA',
#  'PŁASKOWYŻ',
#  'SEJMITAR',
#  'PRECEL',
#  'PLEMIENIE',
#  'PIELMIENIE',
#  'PANTOFEL',
#  'WERSALKA',
#  'TAPCZAN',
#  'PUFA',
#  'PLANDEKA',
#  'SKOROSZYT',
#  'BRANZOLETA',
#  'TLEN',
#  'BERBEĆ',
#  'BOBAS',
#  'OBCASY',
#  'PAZŁOTKO',
#  'BIELIZNA',
#  'MIELIZNA',
#  'SZCZYPTA',
#  'BRYNDZLOWAĆ',
#  'RAFAŁ',
#  'BRYNDAL',
#  'CZERPAK',
#  'SZUFLA',
#  'HIPOKRYSTYK',
#  'SYNEKDOCHA',
#  'NAPLETEK',
#  'STULEJKA',
#  'OBRZEZANIE',
#  'DŻDŻOWNICA',
#  'ĆWIKŁA',
#  'CHRABĄSZCZ',
#  'SZLAFMYCA',
#  'MACHLOJKA',
#  'FELIETON',
#  'PLANETA',
#  'ZASMAŻKA',
#  'TALIZMAN',
#  'MELIORACJA',
#  'PRYWACIARZ',
#  'ZABOBON',
#  'RACICE',
#  'CEWKA',
#  'ALOKACJA',
#  'URLOP',
#  'MAZGAJ',
#  'GAŁGAN',
#  'URWIS',
#  'CYSTERNA',
#  'KUBRAKI',
#  'PORTKI',
#  'KLOAKA',
#  'BERBEĆ',
#  'OBIEŻYŚWIAT',
#  'CZĄBER',
#  'BULGOTANIE',
#  'ABAŻUR',
#  'OKARYNA',
#  'FARSZ',
#  'BRIOSZKA',
#  'BULBASKI',
#  'BOLESŁAW',
#  'PLOTER',
#  'DOSMACZYĆ',
#  'REWERS',
#  'OSOCZE',
#  'MARUDER',
#  'SZABROWNIK',
#  'BATON',
#  'HOBBYSTA',
#  'PEŁEL',
#  'DUBELTÒWKA',
#  'FUZJA',
#  'DUBELTÓWKA',
#  'CYPEL',
#  'KRUCYFIKS',
#  'PSIKUS',
#  'PACHOLĘ',
#  'NIEBOSZCZYK',
#  'GALARETA',
#  'PLUSKWA',
#  'CERATA',
#  'BUDUAR',
#  'BIBELOT',
#  'BISKWIT',
#  'KEKS',
#  'BROSZURA',
#  'BROKAT',
#  'ZBESZCZESZCZENIE',
#  'CUDZY',
#  'ZAKAPIOR',
#  'MAGLOWNICA',
#  'KOMPLEKSY',
#  'DURSZLAK',
#  'SZUMOWINA',
#  'SZUWARY',
#  'SZROT',
#  'TROCINY',
#  'KONFUCJUSZ',
#  'KAPITALIKI',
#  'WERSALIKI',
#  'DELIKATESY',
#  'DEFRAUDACJA',
#  'MALWERSACJA',
#  'SPRZENIEWIERZENIE',
#  'MAKLER',
#  'CZŁONEK',
#  'CZUŁKI',
#  'KASZKA',
#  'REKOLEKCJE',
#  'ABSMAK',
#  'FAJRANT',
#  'PRZYJEMNIACZEK',
#  'PAPILOTY',
#  'PLOTER',
#  'WIWAT',
#  'PONTON',
#  'IMPLOZJA',
#  'IMPETEM',
#  'IMPLEMENTACJA',
#  'SROM',
#  'WICHAJSTER',
#  'BOLEC',
#  'DYNKS',
#  'SZYSZAK',
#  'TALIZMAN',
#  'FARELKA',
#  'FACETKA',
#  'JESTES',
#  'PRODIŻ',
#  'GIF',
#  'GOLASY',
#  'PANTOFLE',
#  'MENISK',
#  'ALOES',
#  'EKIPA',
#  'ZGAGA',
#  'REFLEKTOR',
#  'POMPON',
#  'LUPA',
#  'LUBA',
#  'BULWA',
#  'UBIKACJA',
#  'WYTARABANIĆ',
#  'SIĘ',
#  'EMBLEMAT',
#  'KABACZEK',
#  'OBLEPIĆ',
#  'MAKLERA',
#  'MOLEKUŁY',
#  'HAHAHAHAHAHAHAHA',
#  'KWIT',
#  'WYKWIT',
#  'ZLEWOZMYWAK',
#  'BYDLAK',
#  'SKARŻYPYTA',
#  'RODODENDRON',
#  'KORNISZON',
#  'PLIK',
#  'BRYLANTY',
#  'CZOPEK',
#  'MORDĘGA',
#  'AKWALUNG',
#  'BAJDEWIND',
#  'SZNAPS',
#  'KABESTAN',
#  'RYCZAŁT',
#  'PULTAĆ',
#  'SIĘ',
#  'GALOTY',
#  'WYWALONE',
#  'KOSMOS',
#  'WYPRYSK',
#  'POŚLADEK',
#  'KAJUTA',
#  'KAUCJA',
#  'KOMODA',
#  'KAPSEL',
#  'KLIPS',
#  'KURDYBANEK',
#  'SMARK',
#  'FIGIEL',
#  'ARMATURA',
#  'KANCIAPA',
#  'CZELUŚĆ',
#  'KLOPSIK',
#  'SZCZYPTA',
#  'RUPIEĆ',
#  'ŁACHMANY',
#  'BRYLOWAĆ',
#  'WODEWIL',
#  'DRYLOWNICA',
#  'KLOSZARD',
#  'DRAKA',
#  'KINDERSZTUBA',
#  'ŁASICA',
#  'GAMOŃ',
#  'RUSZT',
#  'ZWYRODNIALEC',
#  'PINEZKA',
#  'MUS',
#  'GRANOLA',
#  'ŻYRANDOL',
#  'ŻEGLUGA',
#  'ŻARŁOK',
#  'ŻEŃ-SZEŃ',
#  'ŻUPA',
#  'ŻUPAN',
#  'SZALUPA',
#  'FECHTUNEK',
#  'RUMPEL',
#  'OWOCEK',
#  'AGREGAT',
#  'ROZPIERDUCHA',
#  'AGREST',
#  'KOCZKODAN',
#  'KAPISZON',
#  'DUBELTÓWKA',
#  'BELKA',
#  'LEKSYKON',
#  'GRUBAS',
#  'SZMAL',
#  'GIEROJ',
#  'WALENTYNKI',
#  'WIERTARKA',
#  'DUPAL',
#  'ZADEK',
#  'POŚLADEK',
#  'GUBERNATOR',
#  'ŚLUZ',
#  'PLEBISCYT',
#  'TURBO',
#  'LETARG',
#  'LIZUS',
#  'ĆMA',
#  'RECYDYWA',
#  'RARYTAS',
#  'DEWOCJONALIA',
#  'BRYGADA',
#  'BRYNDZA',
#  'KONKORDIA',
#  'CEBULARZ',
#  'WERTIKALE',
#  'PSZENŻYTO',
#  'ŻABOT',
#  'GZYMS',
#  'KONDYGNACJA',
#  'COKÓŁ',
#  'CHŁYSTEK',
#  'PAPLANINA',
#  'MAJCHER',
#  'LANDRYNKA',
#  'CHYŻY',
#  'FENKUŁ',
#  'SZAJKA',
#  'SZELKI',
#  'SKARPETKA',
#  'SKURCZYBYK',
#  'KLASZTOR',
#  'SUKINKOT',
#  'MIĘTOLIĆ',
#  'DOBRE',
#  'SŁOWA',
#  'SKUMBRIA',
#  'GLOBTROTER',
#  'MANIPULACJA',
#  'PULA',
#  'PLUCHA',
#  'ZASADZIE',
#  'SORY',
#  'PSZESZYWANICA',
#  'RESORY',
#  'PRZYPOMINAM',
#  'WSZYSTKO',
#  'BEZ',
#  'ZDRABNIANIA',
#  'ŻE',
#  'DANE',
#  'SŁOWO',
#  'JEST',
#  'DOMYŚLNIE',
#  'PRZESZYWANICA',
#  'ZE',
#  'KTOS',
#  'PILNUJE',
#  'MISIURKA',
#  'SMACZLIWKA',
#  'KLUCHY',
#  'KUPAŻ',
#  'SYNDROM',
#  'DOBRE',
#  'PRZYDUPAS',
#  'ŁACH',
#  'ŁACHUDRA',
#  'ŁACHMYTA',
#  'LAMPUCERA',
#  'KAPITALISTA',
#  'FLAKON',
#  'ŁAJDAK',
#  'ŁAPSERDAK',
#  'SZAŁAPUT',
#  'SZURZY',
#  'ŚWIEKRA',
#  'AGNAT',
#  'KOGNAT',
#  'PASZENOG',
#  'PORTIER',
#  'DOBROBYT',
#  'ROLMOPS',
#  'PASZKWIL',
#  'DRYLOWAĆ',
#  'LEBIEGA',
#  'BUKSY',
#  'GWASZ',
#  'BOMBONIERKA',
#  'ELEWACJA',
#  'BUŃCZUCZNY',
#  'HUNCWOT',
#  'SMAKOŁYK',
#  'IMBRYK',
#  'GAŁGAN',
#  'FISTASZKI',
#  'PAŁĄK',
#  'MEDYKAMENTY',
#  'TRĄBKA',
#  'SITODRUK',
#  'KNAGA',
#  'PRZEPROCHA',
#  'SZPIKULEC',
#  'NICPOŃ',
#  'SZACH',
#  'TURNIEJ',
#  'LIZENA',
#  'CERATA',
#  'TOTEM',
#  'SKUMBRIA',
#  'ALCYBIADES',
#  'MADRYGAŁ',
#  'ANCYMON',
#  'MIGDALIĆ',
#  'POJEZIERZE',
#  'DAMULKA',
#  'DURNOTA',
#  'BEBECHY',
#  'BERBEĆ',
#  'KLASER',
#  'KLASTER',
#  'ANDRUTY',
#  'BAŁAMUT',
#  'HOCHSZTAPLER',
#  'USTROJSTWO',
#  'SZYSZYNKA',
#  'FELIETON',
#  'CWANIAK',
#  'GLOBTROTER',
#  'BADZIEWIE',
#  'NADZIENIE',
#  'MIERZWIENIE',
#  'PIELMIENIE',
#  'PIELENOE',
#  'UPS',
#  'FISZBINY',
#  'SZTYLET',
#  'RAPIER',
#  'PAPIER',
#  'PIERNIK',
#  'INTERLOKUTOR',
#  'WIZAŻ',
#  'ZAKĄSKA',
#  'SALWA',
#  'KLAJSTER',
#  'HUBBA',
#  'HUBA',
#  'NABUCHODONOZOR',
#  'OOOO',
#  'SZPAGAT',
#  'DESKOROLKA',
#  'DRATWA',
#  'BRZYTWA',
#  'HIGIENISTKA',
#  'SZCZUR',
#  'PACIOREK',
#  'SZPARA-G',
#  'KAPOTA',
#  'SAKWA',
#  'FIKSACJA',
#  'FIKOŁEK',
#  'SZPARGAŁY',
#  'WYPLATAĆ',
#  'DRUMLIN',
#  'KULISY',
#  'KLUCZNIK',
#  'MILENIUM',
#  'PORZECZKA',
#  'MIRABELA',
#  'GOŁODUPCY',
#  'CHŁYSTEK',
#  'SZUMOWINA',
#  'SZLAGIER',
#  'SZPICRUTA',
#  'POLITYKA',
#  'RZĘSA',
#  'WODNA',
#  'ŻABIŚCIEK',
#  'PALCE',
#  'GRZEBIUSZKA',
#  'RODZYNKA',
#  'BARYŁA',
#  'KORNIK',
#  'CIUCIUBABKA',
#  'SZCZYPIORNISTA',
#  'OSESEK',
#  'KROCHMAL',
#  'KRAKSA',
#  'GAMOŃ',
#  'KOMPLEKSY',
#  'SALCESON',
#  'POKARM',
#  'PERYPETIE',
#  'ODMĘT',
#  'BAGATELA',
#  'SELEDYNOWY',
#  'PALNIK',
#  'RÓŻDŻKA',
#  'LĄDOLÓD',
#  'SZCZEBELKI',
#  'WAFEL',
#  'WYKŁADZINA',
#  'WOREK',
#  'DUBELTÓWKA',
#  'KLASÓWKA',
#  'KARNET',
#  'WRZAWA',
#  'BALERINY',
#  'TYŁEK',
#  'FITOTRON',
#  'IMPONDERABILIA',
#  'SPLENDOR',
#  'BĘKART',
#  'GARGULEC',
#  'ABSZTYFIKANT',
#  'FIASKO',
#  'TURNUS',
#  'PODDUPNIK',
#  'BOCZNIAKI',
#  'KASZKIET',
#  'BRYCZESY',
#  'MITENKI',
#  'OPRYCHÓWKA',
#  'BETONIARKA',
#  'PODPŁOMYK',
#  'LIBACJA',
#  'BROMELINA',
#  'PRALINY',
#  'KINKIET',
#  'ŚRUTÓWKA',
#  'TRYTYTKA',
#  'DŻDŻY',
#  'BUKŁAK',
#  'KORALIK',
#  'PERLIK',
#  'KURZAJKA',
#  'BAOBAB',
#  'KATAKUMBY',
#  'KATARAKTA',
#  'MENAŻKA',
#  'PELARGONIA',
#  'PERSYMONY',
#  'PAPROCH',
#  'PIPETA',
#  'WARCHLAK',
#  'PEKAESY',
#  'MOLOCH',
#  'SZTRUCEL',
#  'SZTUCER',
#  'KLINGA',
#  'PODOMKA',
#  'DŻDŻYSTY',
#  'PAWLACZ',
#  'GAPULKA',
#  'DRYWUTNIA',
#  'BOESIADA',
#  'MAJTASY',
#  'MĘCZENNICY',
#  'GRZYBOBRANIE',
#  'KAPISZONY',
#  'KUFEL',
#  'KROPKA',
#  'WĘDLINA',
#  'MORO',
#  'BITKA',
#  'WSAD',
#  'HARMIDER',
#  'LUPA',
#  'GRDYKA',
#  'FIGURKA',
#  'DZIUPLA',
#  'GIF',
#  'FANTOM',
#  'TREFNIŚ',
#  'ĆWIKŁA',
#  'EKIERKA',
#  'KREPINA',
#  'KOŁCZAN',
#  'GIPHY',
#  'PASMANTERIA',
#  'PSZCZO£A',
#  'BUKSZPAN',
#  'SZELĄG',
#  'FISKUS',
#  'GABARYTY',
#  'POMADKA',
#  'SZCZYPIOR',
#  'KORPUS',
#  'GALOTY',
#  'DEGRENGOLADA',
#  'DRYBLAS',
#  'AMUNICJA',
#  'BUDOWLANIEC',
#  'BULDOG',
#  'CHLAPAKI',
#  'ALIKWOTY',
#  'LINOLEUM',
#  'KOŁPAK',
#  'SZCZUDŁA',
#  'DZYNDZEL',
#  'WODZIREJ',
#  'SPRYCIULA',
#  'SPIRULINA',
#  'BALERON',
#  'REPERACJA',
#  'MAJSTER',
#  'PAPIRUS',
#  'TURBAN',
#  'GIRLANDA',
#  'MAMINSYNEK',
#  'SPAŚLAK',
#  'WICHRZYCIEL',
#  'POPELINA',
#  'BOLEC',
#  'WERNYHORA',
#  'MARMOLADA',
#  'LETARG',
#  'MRUK',
#  'REWIRY',
#  'REMAMENT',
#  'REPUBLIKANCI',
#  'KALAFIOR',
#  'CEREGIELIĆ',
#  'SIĘ',
#  'MOCZYMORDA',
#  'KABANOS',
#  'CHOCHLIK',
#  'BOKOBRODY',
#  'ŁUPINA',
#  'ŁOJOTOK',
#  'ATLETA',
#  'NIBYNÓŻKI',
#  'RIKSZA',
#  'WYĆWIKIN',
#  'BIAŁY',
#  'GAŁKA',
#  'MUSZKATOŁOWA',
#  'MIELENIE',
#  'PASZA',
#  'WOLUMIN',
#  'KARAKAL',
#  'PRÓSZENIE',
#  'UKWIAŁ',
#  'SZLAM',
#  'FATAMORGANA',
#  'DZIERLATKA',
#  'OFERMA',
#  'GAGATEK',
#  'OBDARTUSY',
#  'MELODRAMATY',
#  'PRAWOŚLAZ',
#  'MINARET',
#  'IMADŁO',
#  'EJAKULAT',
#  'MAMIDŁO',
#  'PASTERNAK',
#  'MAJATERSZTYK',
#  'SPODZICHY',
#  'HADŻYT',
#  'OSIŁEK',
#  'RUMPLOWAĆ',
#  'SELEDYNOWY',
#  'KARNISZ',
#  'LUMPENPROLETARIAT',
#  'AMBARAS',
#  'ZAZDROSTKA',
#  'LATYFUNDIUM',
#  'KAPUCYN',
#  'SKUN',
#  'ZWICHNIĘTY',
#  'AKWEN',
#  'FACJATA',
#  'KRYPTA',
#  'CYMES',
#  'SZEKLA',
#  'KLAWY',
#  'DYSCYPLINA',
#  'ZAPLECZE',
#  'WODOTRYSK',
#  'BALLADA',
#  'NATRYSK',
#  'PŁYWALNIA',
#  'TERMOFOR',
#  'POTENCJAŁ',
#  'MOTEL',
#  'DOMATOR',
#  'NOWICJUSZ',
#  'ELEWACJA',
#  'SZKRAB',
#  'NOBLISTA',
#  'BABSZTYL',
#  'SEMAFOR',
#  'PIECZARA',
#  'MELINA',
#  'FILUT',
#  'FIUT',
#  'BAMBUKO',
#  'PROLIFERACJA',
#  'GABARDYNA',
#  'SKOROSZYT',
#  'GABARYTY',
#  'SZCZYTY',
#  'UKRYTY',
#  'RAPGRA',
#  'HARPAGAN',
#  'WINKIEL',
#  'WYGA',
#  'ARABESKA',
#  'SMURGLE',
#  'ESPADRYLE',
#  'BALANS',
#  'ZWARCIE',
#  'WARCHLAK',
#  'GNIDA',
#  'MARAZM',
#  'WIERCIPIĘTA',
#  'PACHA',
#  'DILDO',
#  'ŚCIERWO',
#  'ŁAPSERDAK',
#  'EKWIWALENT',
#  'FROTKA',
#  'SANITARIAT',
#  'SARDYNKA',
#  'LIZERGINA',
#  'FATYGANT',
#  'MIKRODERMABRAZJA',
#  'REHABILITANT',
#  'LICZYKRUPA',
#  'PAŁĄK',
#  'TERPENTYNA',
#  'KONSOLA',
#  'FAJRANT',
#  'BALEJAŻ',
#  'LIANA',
#  'MORWA',
#  'ŻMUD',
#  'CIUPAGA',
#  'FURTKA',
#  'FURMANKA',
#  'OKARYNA',
#  'ZIĘĆ',
#  'TELEBIM',
#  'WODOCIĄG',
#  'FILUTERNY',
#  'FRAMUGA',
#  'JAD',
#  'ZAJADY',
#  'MASZKARON',
#  'KĄKOL',
#  'PIERDEL',
#  'BIMBER',
#  'ZAJZAJER',
#  'ZACIER',
#  'WAŁÓWKA',
#  'PRYCZA',
#  'LAKTACJA',
#  'KONFISKACJA',
#  'EPISKOPAT',
#  'CHLAPOTA',
#  'PONTON',
#  'GILDIA',
#  'GILZA',
#  'RULON',
#  'BLETKA',
#  'MELDUNEK',
#  'ZAŚLEPKA',
#  'PÓŁBUT',
#  'EPISKOPAT',
#  'TRASZKA',
#  'MIZERIA',
#  'MIZERYJKORDIA',
#  'SUS',
#  'TRYWIALNY',
#  'JAŹŃ',
#  'KOCIOKWIK',
#  'CHWAT',
#  'ABONENT',
#  'ABONAMENT',
#  'RYNSZTOK',
#  'PLEREZA',
#  'TRANSPARENT',
#  'WYWROTKA',
#  'KUMOSZKA',
#  'PRZEKUPA',
#  'WŁÓCZĘGA',
#  'KATAFALK',
#  'AUTOKLAW',
#  'POTWARZ',
#  'POŁAĆ',
#  'MANKAMENT',
#  'DZIERŻAWA',
#  'KUPA',
#  'SITO',
#  'GLAZURA',
#  'SMYKAŁKA',
#  'DRĄG',
#  'KASETON',
#  'SZPALER',
#  'RZĘCH',
#  'FRAJDA',
#  'ŁEPETYNA',
#  'ANGAŻ',
#  'KAJUTA',
#  'SZTUĆCE',
#  'GRONOSTAJ',
#  'SZYPUŁKA',
#  'MAJSTER',
#  'BRZASK',
#  'SZALUPA',
#  'PUZDERKO',
#  'GWIZDEK',
#  'DESEŃ',
#  'HOSPICJUM',
#  'BONIFIKATA',
#  'PENDOLINO',
#  'NAWIAS',
#  'PYTON',
#  'LAMER',
#  'PROPORCZYK',
#  'UKROP',
#  'BIURWA',
#  'NIEŻYT',
#  'IMPET',
#  'WISKOZA',
#  'NURT',
#  'CIŻEMKA',
#  'HEJNAŁ',
#  'BAMBETLE',
#  'FARFOCEL',
#  'SZPENIO',
#  'KATAMARAN',
#  'BATYSKAF',
#  'GLON',
#  'NIECHLUJ',
#  'INSTYNKT',
#  'PIĘKNODUCH',
#  'SPECJAŁ',
#  'PRÓCHNIAK',
#  'FASON',
#  'KIKUT',
#  'WOJAŻ',
#  'WIDNOKRĄG',
#  'RABARBAR',
#  'ZADYSZKA',
#  'DZIWOLĄG',
#  'ZAKAMAREK',
#  'POGAWĘDKA',
#  'RABAN',
#  ...]
